# %% [markdown]
# <a href="https://colab.research.google.com/github/PX2145-2025/week-1-b-sebclerey/blob/main/obstech_exoplanets_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
target = np.array([175930,174660,174800,173950,172870,171560,170220,170720,172050,174130,175230,175950])
cal1 = np.array([105680,104740,106190,106910,106440,106090,104620,105440,105310,105160,105080,105760])
cal2 = np.array([76283,76019,76433,77369,76851,75894,76292,75762,75783,76638,75497,76481,])
cal3 = np.array([33082,33572,33654,33608,33622,33026,32508,33049,32903,33121,33458,33801])
time = np.array([])

ratiotargetovercal1 = target/cal1
ratiocal1overcal2 = cal1/cal2
ratiocal2overcal3 = cal2/cal3

plt.plot(ratiotargetovercal1)
plt.figure()
plt.plot(ratiocal1overcal2)
plt.figure()
plt.plot(ratiocal2overcal3)
